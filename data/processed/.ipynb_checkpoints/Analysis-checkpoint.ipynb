# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import operator
from operator import itemgetter
import itertools

# %% [markdown]
# Notes:
# 1. OOV - num token(s)
# 2. Align vocabularies language-wise

# %%
# Meta statistics
sl_set = []
OOV_count_set = []
vocab_count_set = []
OOV_size_set = []
vocab_size_set = []
sl_stats_set = []
m_en = []
m_fr = []
p_en = []
p_fr = []

# %%
# start = time.perf_counter()
print("Monolingual English")
bow = []
sentence_length = []
vocab_alpha = {}
OOV = {}
with open('unaligned.en', "r") as text_file:
    for line in text_file:
        stripped_line = line.strip()
        bow.extend(stripped_line.split())
        sentence_length.append(len(stripped_line.split()))

# Word Count + Dictionary    
print("Word Count Total: ", sum(sentence_length))
vocab = pd.DataFrame(list(zip(bow, bow, [1] * len(bow))), columns =['Word', 'Token','Count']).groupby('Word',sort=False)['Token'].count().to_dict()
for word, count in vocab.items():
    if any(c.isalpha() for c in word):
        vocab_alpha[word] = count
    else:
        OOV[word] = count
print("Total Vocab Size by Words: ", len(vocab))
print("OOV Size: ", len(OOV))
print("OOV Word Count:", sum(OOV.values()))
print("Net Vocab Size: ", len(vocab_alpha))
print("In Vocab Word Count: ", sum(vocab_alpha.values()))

# Word Frequency
wf = np.asarray(list(vocab_alpha.values()))
wf_metrics = {"min": np.amin(wf), "max": np.amax(wf), "mean": np.mean(wf), "std": np.std(wf)}
print("Word Frequency Info: ", wf_metrics)

# Most Frequent Words
sorted_vocab = dict(sorted(vocab_alpha.items(), key=operator.itemgetter(1),reverse=True))
top = dict(itertools.islice(sorted_vocab.items(), 10))
print("Most Common Words: ", top)

# Sentence Lengths
sl = np.asarray(sentence_length)
sentence_len_metrics = {"min": np.amin(sl), "max": np.amax(sl), "mean": np.mean(sl), "std": np.std(sl)}
print("Sentence Length Info: ",sentence_len_metrics)

# Append to metadata
sl_set.append(sl)
OOV_count_set.append(len(OOV))
vocab_count_set.append(len(vocab_alpha))
OOV_size_set.append(sum(OOV.values()))
vocab_size_set.append(sum(vocab_alpha.values()))
# Out:
# Monolingual English
# Word Count Total:  8820344
# Total Vocab Size by Words:  60008
# OOV Size:  2715
# OOV Word Count: 148263
# Net Vocab Size:  57293
# In Vocab Word Count:  8672081
# Word Frequency Info:  {'min': 1, 'max': 585841, 'mean': 151.36370935367322, 'std': 3697.307529119359}
# Most Common Words:  {'the': 585841, 'to': 279419, 'of': 275207, 'and': 226316, 'in': 190930, 'a': 163817, 'is': 154142, 'that': 153805, 'i': 110767, 'we': 99798}
# Sentence Length Info:  {'min': 1, 'max': 180, 'mean': 18.608320675105485, 'std': 9.763772743797661}

# %%
plt.figure(figsize=[15,10])
plt.hist(sl, bins=50)
plt.title("Monolingual English, Sentence Length Distribution",fontsize=20)
plt.ylabel('Number of Sentences',fontsize=18)
plt.xlabel('Sentence Length',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('uni_en_sen_len_dist.jpg')

# %%
w = list(map(itemgetter(1), top.items()))[::-1]
c = list(map(itemgetter(0), top.items()))[::-1]
m_en.append(w)
m_en.append(c)
plt.figure(figsize=[15,6])
plt.barh(c,w)
plt.title("Monolingual English, Top 10 Words" ,fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('uni_en_freq_w.jpg')

# %%
print("Monolingual French")
bow = []
sentence_length = []
vocab_alpha = {}
OOV = {}
with open('unaligned.fr', "r") as text_file:
    for line in text_file:
        stripped_line = line.strip()
        bow.extend(stripped_line.split())
        sentence_length.append(len(stripped_line.split()))

# Word Count + Dictionary    
print("Word Count Total: ", sum(sentence_length))
vocab = pd.DataFrame(list(zip(bow, bow, [1] * len(bow))), columns =['Word', 'Token','Count']).groupby('Word',sort=False)['Token'].count().to_dict()
for word, count in vocab.items():
    if any(c.isalpha() for c in word):
        vocab_alpha[word] = count
    else:
        OOV[word] = count
print("Total Vocab Size by Words: ", len(vocab))
print("OOV Size: ", len(OOV))
print("OOV Word Count:", sum(OOV.values()))
print("Net Vocab Size: ", len(vocab_alpha))
print("In Vocab Word Count: ", sum(vocab_alpha.values()))

# Word Frequency
wf = np.asarray(list(vocab_alpha.values()))
wf_metrics = {"min": np.amin(wf), "max": np.amax(wf), "mean": np.mean(wf), "std": np.std(wf)}
print("Word Frequency Info: ", wf_metrics)

# Most Frequent Words
sorted_vocab = dict(sorted(vocab_alpha.items(), key=operator.itemgetter(1),reverse=True))
top = dict(itertools.islice(sorted_vocab.items(), 10))
print("Most Common Words: ", top)

# Sentence Lengths
sl = np.asarray(sentence_length)
sentence_len_metrics = {"min": np.amin(sl), "max": np.amax(sl), "mean": np.mean(sl), "std": np.std(sl)}
print("Sentence Length Info: ",sentence_len_metrics)

# Append to metadata
sl_set.append(sl)
OOV_count_set.append(len(OOV))
vocab_count_set.append(len(vocab_alpha))
OOV_size_set.append(sum(OOV.values()))
vocab_size_set.append(sum(vocab_alpha.values()))
# Out:
# Monolingual French
# Word Count Total:  9746232
# Total Vocab Size by Words:  83314
# OOV Size:  2545
# OOV Word Count: 151899
# Net Vocab Size:  80769
# In Vocab Word Count:  9594333
# Word Frequency Info:  {'min': 1, 'max': 462046, 'mean': 118.78731939234112, 'std': 3017.9261930933653}
# Most Common Words:  {'de': 462046, 'la': 298409, 'et': 211018, 'le': 209347, 'les': 197208, 'à': 185613, "l'": 171036, 'des': 163300, 'que': 147798, 'en': 135833}
# Sentence Length Info:  {'min': 1, 'max': 224, 'mean': 20.561670886075948, 'std': 10.823182771689924}

# %%
w = list(map(itemgetter(1), top.items()))[::-1]
c = list(map(itemgetter(0), top.items()))[::-1]
m_fr.append(w)
m_fr.append(c)

plt.figure(figsize=[15,6])
plt.barh(c,w)
plt.title("Monolingual French, Top 10 Words" ,fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('uni_fr_freq_w.jpg')

# %%
plt.figure(figsize=[15,10])
plt.hist(sl, bins=50)
plt.title("Monolingual French, Sentence Length Distribution",fontsize=20)
plt.ylabel('Number of Sentences',fontsize=18)
plt.xlabel('Sentence Length',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('uni_fr_sen_len_dist.jpg')

# %%
print("Parallel English")
bow = []
sentence_length = []
vocab_alpha = {}
OOV = {}
with open('train.lang1', "r") as text_file:
    for line in text_file:
        stripped_line = line.strip()
        bow.extend(stripped_line.split())
        sentence_length.append(len(stripped_line.split()))

# Word Count + Dictionary    
print("Word Count Total: ", sum(sentence_length))
vocab = pd.DataFrame(list(zip(bow, bow, [1] * len(bow))), columns =['Word', 'Token','Count']).groupby('Word',sort=False)['Token'].count().to_dict()
for word, count in vocab.items():
    if any(c.isalpha() for c in word):
        vocab_alpha[word] = count
    else:
        OOV[word] = count
print("Total Vocab Size by Words: ", len(vocab))
print("OOV Size: ", len(OOV))
print("OOV Word Count:", sum(OOV.values()))
print("Net Vocab Size: ", len(vocab_alpha))
print("In Vocab Word Count: ", sum(vocab_alpha.values()))

# Word Frequency
wf = np.asarray(list(vocab_alpha.values()))
wf_metrics = {"min": np.amin(wf), "max": np.amax(wf), "mean": np.mean(wf), "std": np.std(wf)}
print("Word Frequency Info: ", wf_metrics)

# Most Frequent Words
sorted_vocab = dict(sorted(vocab_alpha.items(), key=operator.itemgetter(1),reverse=True))
top = dict(itertools.islice(sorted_vocab.items(), 10))
print("Most Common Words: ", top)

# Sentence Lengths
sl_en_p = np.asarray(sentence_length)
sentence_len_metrics_en_p = {"min": np.amin(sl), "max": np.amax(sl), "mean": np.mean(sl), "std": np.std(sl)}
print("Sentence Length Info: ", sentence_len_metrics)

# Append to metadata
sl_set.append(sl)
OOV_count_set.append(len(OOV))
vocab_count_set.append(len(vocab_alpha))
OOV_size_set.append(sum(OOV.values()))
vocab_size_set.append(sum(vocab_alpha.values()))
# Out:
# Parallel English
# Word Count Total:  205361
# Total Vocab Size by Words:  13657
# OOV Size:  341
# OOV Word Count: 3547
# Net Vocab Size:  13316
# In Vocab Word Count:  201814
# Word Frequency Info:  {'min': 1, 'max': 13787, 'mean': 15.155752478221688, 'std': 178.616138871287}
# Most Common Words:  {'the': 13787, 'of': 6452, 'to': 6432, 'and': 5259, 'in': 4384, 'a': 3805, 'is': 3617, 'that': 3573, 'i': 2650, 'it': 2287}
# Sentence Length Info:  {'min': 1, 'max': 224, 'mean': 20.561670886075948, 'std': 10.823182771689924}

# %%
plt.figure(figsize=[15,10])
plt.hist(sl, bins=50)
plt.title("Parallel Examples, English, Sentence Length Distribution",fontsize=20)
plt.ylabel('Number of Sentences',fontsize=18)
plt.xlabel('Sentence Length',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('p_en_sen_len_dist.jpg')

# %%
w = list(map(itemgetter(1), top.items()))[::-1]
c = list(map(itemgetter(0), top.items()))[::-1]
p_en.append(w)
p_en.append(c)
plt.figure(figsize=[15,6])
plt.barh(c,w)
plt.title("Parallel Examples, English, Top 10 Words" ,fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('p_en_freq_w.jpg')

# %%
print("Parallel French")
bow = []
sentence_length = []
vocab_alpha = {}
OOV = {}
with open('train.lang2', "r") as text_file:
    for line in text_file:
        stripped_line = line.strip()
        bow.extend(stripped_line.split())
        sentence_length.append(len(stripped_line.split()))

# Word Count + Dictionary    
print("Word Count Total: ", sum(sentence_length))
vocab = pd.DataFrame(list(zip(bow, bow, [1] * len(bow))), columns =['Word', 'Token','Count']).groupby('Word',sort=False)['Token'].count().to_dict()
for word, count in vocab.items():
    if any(c.isalpha() for c in word):
        vocab_alpha[word] = count
    else:
        OOV[word] = count
print("Total Vocab Size by Words: ", len(vocab))
print("OOV Size: ", len(OOV))
print("OOV Word Count:", sum(OOV.values()))
print("Net Vocab Size: ", len(vocab_alpha))
print("In Vocab Word Count: ", sum(vocab_alpha.values()))

# Word Frequency
wf = np.asarray(list(vocab_alpha.values()))
wf_metrics = {"min": np.amin(wf), "max": np.amax(wf), "mean": np.mean(wf), "std": np.std(wf)}
print("Word Frequency Info: ", wf_metrics)

# Most Frequent Words
sorted_vocab = dict(sorted(vocab_alpha.items(), key=operator.itemgetter(1),reverse=True))
top = dict(itertools.islice(sorted_vocab.items(), 10))
print("Most Common Words: ", top)

# Sentence Lengths
sl = np.asarray(sentence_length)
sentence_len_metrics = {"min": np.amin(sl), "max": np.amax(sl), "mean": np.mean(sl), "std": np.std(sl)}
print("Sentence Length Info: ",sentence_len_metrics)

# Append to metadata
sl_set.append(sl)
OOV_count_set.append(len(OOV))
vocab_count_set.append(len(vocab_alpha))
OOV_size_set.append(sum(OOV.values()))
vocab_size_set.append(sum(vocab_alpha.values()))
# Out:
# Parallel French
# Word Count Total:  227856
# Total Vocab Size by Words:  18222
# OOV Size:  327
# OOV Word Count: 3792
# Net Vocab Size:  17895
# In Vocab Word Count:  224064
# Word Frequency Info:  {'min': 1, 'max': 10548, 'mean': 12.521039396479464, 'std': 141.36399443666133}
# Most Common Words:  {'de': 10548, 'la': 6400, 'et': 4612, 'le': 4525, 'à': 4335, 'les': 3982, 'des': 3675, "l'": 3625, 'que': 3431, 'est': 3032}
# Sentence Length Info:  {'min': 1, 'max': 105, 'mean': 20.714181818181817, 'std': 10.912683977982034}

# %%
plt.figure(figsize=[15,9])
plt.hist(sl, bins=50)
plt.title("Parallel Examples, French, Sentence Length Distribution",fontsize=20)
plt.ylabel('Number of Sentences',fontsize=18)
plt.xlabel('Sentence Length',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('p_fr_sen_len_dist.jpg')

# %%
w = list(map(itemgetter(1), top.items()))[::-1]
c = list(map(itemgetter(0), top.items()))[::-1]
p_fr.append(w)
p_fr.append(c)
plt.figure(figsize=[15,6])
plt.barh(c,w)
plt.title("Parallel Examples, French, Top 10 Words" ,fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('p_fr_freq_w.jpg')

# %%
# Alignment
mono_fr_wc = m_fr[0]
mono_fr_w = m_fr[1]
pe_fr_wc = p_fr[0]
pe_fr_w = p_fr[1]
mono_en_wc = m_en[0]
mono_en_w = m_en[1]
pe_en_wc = p_en[0]
pe_en_w = p_en[1]

# %%
# print(mono_fr_wc)

# %%
plt.figure(figsize=[15,9])
plt.title("Box Plot, Sentence Length Distribution" ,fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
columns=["Monolingual English", "Monolingual French", "Parallel English", "Paralle French"]

sns.boxplot(data=sl_set)
plt.xticks(plt.xticks()[0], columns)

plt.savefig('box_wc.jpg')

# %%
# OOVs in relation to real vocab\n",
groups = ['Unaligned FR', 'Unalgined EN', 'Parallel FR', 'Parallel EN']
oovs = np.asarray(OOV_size_set)
reals = np.asarray(vocab_size_set)
ind = [x for x, _ in enumerate(groups)]

plt.figure(figsize=[15,9])

plt.bar(ind, oovs, width=0.3, label='silvers', color='blue', bottom=reals)
plt.bar(ind, reals, width=0.3, label='bronzes', color='red')

plt.xticks(ind, groups)
plt.ylabel("Vocab Size")
plt.xlabel("Groups")
plt.legend(loc="upper right")
plt.title("OOVs vs Vocab")

plt.show()

# %%
oovs
# Out:
# array([148263, 151899,   3547,   3792])
